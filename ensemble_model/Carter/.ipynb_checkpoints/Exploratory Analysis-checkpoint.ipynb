# %%
# import packages
import pandas as pd
import numpy as np
import sklearn as sk
from Utils import matrix_loader as MatrixLoader

# %%
# load files into matrix
matrixLoader = MatrixLoader.Matrix_loader('/home/carter/Documents/CS-188-Ensemble-ML-Model/ensemble_model/Data')

# %%
(trainA, trainb, verA, verb) = matrixLoader.load_raw_mats()

# %%
trainA_df = pd.DataFrame(trainA)
trainA_df
# Out:
#           0         1         2         3         4         5         6     \
# 0    -0.000289  0.000128  0.000446  0.000266 -0.000115 -0.000951  0.000146
# 1    -0.000289  0.000128  0.000446  0.000266 -0.000115 -0.000951  0.000146
# 2    -0.000289  0.000128  0.000446  0.000266 -0.000115 -0.000951  0.000146
# 3    -0.000289  0.000128  0.000446  0.000266 -0.000115 -0.000951  0.000146
# 4    -0.000289  0.000128  0.000446  0.000266 -0.000115 -0.000951  0.000146
# 5    -0.000289  0.000128  0.000446  0.000266 -0.000115 -0.000951  0.000146
# 6    -0.000289  0.000128  0.000446  0.000266 -0.000115 -0.000951  0.000146
# 7    -0.000289  0.000128  0.000446  0.000266 -0.000115 -0.000951  0.000146
# 8    -0.000289  0.000128  0.000446  0.000266 -0.000115 -0.000951  0.000146
# 9    -0.000289  0.000128  0.000446  0.000266 -0.000115 -0.000951  0.000146
# 10   -0.000289  0.000128  0.000446  0.000266 -0.000115 -0.000951  0.000146
# ...

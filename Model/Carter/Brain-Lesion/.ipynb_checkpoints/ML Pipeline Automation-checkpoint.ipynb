# %%
# external imports
import imp
module_name = 'Model.Utils.utility_functions'
desktop_module_path = 'C:\\Users\\Carter Wu\\Documents\\CS 188\\Brain-Lesion-Predictive-Model\\Model\\Utils\\utility_functions.py'
module_path = '/home/carter/Documents/Brain-Lesion-Predictive-Model/Model/Utils/utility_functions.py'
utility_functions = imp.load_source(module_name, desktop_module_path)

# import libraries
import pickle
import pandas as pd
import numpy as np
import sklearn as sk
import random
import itertools
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# model
from tpot import TPOTClassifier

# use path to get data
desktop_path = 'C:\\Users\\Carter Wu\\Documents\\CS 188\\Brain-Lesion-Predictive-Model\\Data\\MRI-DATA\\train_data.csv'
path = '/home/carter/Documents/Brain-Lesion-Predictive-Model/Data/MRI-DATA/train_data.csv'
(X, Y, data) = utility_functions.get_csv(desktop_path)

# %%
# split data
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.75, test_size=0.25)

# %%
tpot = TPOTClassifier(generations=5, population_size=20, verbosity=3)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))
tpot.export('tpot_mnist_pipeline.py')
# Out:
# C:\Users\Carter Wu\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 29 operators have been imported by TPOT.
# _pre_test decorator: _generate: num_test=0 precomputed was provided as affinity. Ward can only work with euclidean distances.
# _pre_test decorator: _generate: num_test=0 X contains negative values.
# _pre_test decorator: _generate: num_test=1 Unsupported set of arguments: The combination of penalty='l1' and loss='logistic_regression' are not supported when dual=True, Parameters: penalty='l1', loss='logistic_regression', dual=True
# _pre_test decorator: _generate: num_test=0 Input X must be non-negative
# _pre_test decorator: _generate: num_test=1 Input X must be non-negative
# _pre_test decorator: _generate: num_test=0 Expected n_neighbors <= n_samples,  but n_samples = 50, n_neighbors = 66
# _pre_test decorator: _generate: num_test=0 Input X must be non-negative
# _pre_test decorator: _generate: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='logistic_regression' are not supported when dual=True, Parameters: penalty='l1', loss='logistic_regression', dual=True
#           on Progress:   1%|          | 1/120 [09:33<18:57:17, 573.42s/pipeline]
# Skipped pipeline #2 due to time out. Continuing to the next pipeline.
#           on Progress:   4%|▍         | 5/120 [19:30<14:15:11, 446.18s/pipeline]
# Skipped pipeline #6 due to time out. Continuing to the next pipeline.
#           on Progress:   8%|▊         | 9/120 [36:35<12:00:01, 389.21s/pipeline]
# Skipped pipeline #10 due to time out. Continuing to the next pipeline.
#           on Progress:  11%|█         | 13/120 [1:17:43<13:35:52, 457.50s/pipeline]
# Skipped pipeline #16 due to time out. Continuing to the next pipeline.
#           on Progress:  14%|█▍        | 17/120 [1:19:19<9:22:13, 327.51s/pipeline]
# _pre_test decorator: _random_mutation_operator: num_test=0 Unsupported set of arguments: The combination of penalty='l1' and loss='squared_hinge' are not supported when dual=True, Parameters: penalty='l1', loss='squared_hinge', dual=True
#           on Progress:  18%|█▊        | 21/120 [1:36:33<12:56:16, 470.47s/pipeline]
# Skipped pipeline #22 due to time out. Continuing to the next pipeline.
#           on Progress:  21%|██        | 25/120 [1:52:25<10:34:27, 400.71s/pipeline]
# Skipped pipeline #27 due to time out. Continuing to the next pipeline.
#           on Progress:  24%|██▍       | 29/120 [3:26:03<17:44:28, 701.86s/pipeline]
# Skipped pipeline #32 due to time out. Continuing to the next pipeline.
#           on Progress:  28%|██▊       | 33/120 [3:48:46<14:20:38, 593.55s/pipeline]
# Skipped pipeline #33 due to time out. Continuing to the next pipeline.
#           on Progress:  31%|███       | 37/120 [3:56:02<10:19:58, 448.17s/pipeline]
# Generation 1 - Current Pareto front scores:
#           on Progress:  33%|███▎      | 40/120 [3:56:02<9:57:33, 448.17s/pipeline]
# 1	0.962933304617718	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=1.0, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=14, ExtraTreesClassifier__n_estimators=DEFAULT)
#           on Progress:  33%|███▎      | 40/120 [3:56:02<9:57:33, 448.17s/pipeline]
#           on Progress:  33%|███▎      | 40/120 [3:56:03<6:58:23, 313.79s/pipeline]
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
#           on Progress:  33%|███▎      | 40/120 [3:56:03<6:58:23, 313.79s/pipeline]
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
#           on Progress:  36%|███▌      | 43/120 [4:07:35<6:10:39, 288.83s/pipeline]
# Skipped pipeline #45 due to time out. Continuing to the next pipeline.
#           on Progress:  39%|███▉      | 47/120 [4:20:04<5:14:19, 258.35s/pipeline]
# Skipped pipeline #49 due to time out. Continuing to the next pipeline.
#           on Progress:  49%|████▉     | 59/120 [4:30:26<1:59:34, 117.61s/pipeline]
# Generation 2 - Current Pareto front scores:
#           on Progress:  49%|████▉     | 59/120 [4:30:26<1:59:34, 117.61s/pipeline]
# 1	0.962933304617718	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=1.0, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=14, ExtraTreesClassifier__n_estimators=DEFAULT)
#           on Progress:  49%|████▉     | 59/120 [4:30:26<1:59:34, 117.61s/pipeline]
#           on Progress:  49%|████▉     | 59/120 [4:30:26<1:59:34, 117.61s/pipeline]
# _pre_test decorator: _random_mutation_operator: num_test=0 Input X must be non-negative
#           on Progress:  53%|█████▎    | 64/120 [7:50:56<15:39:59, 1007.13s/pipeline]
# Skipped pipeline #67 due to time out. Continuing to the next pipeline.
#           on Progress:  63%|██████▎   | 76/120 [8:14:08<5:10:25, 423.31s/pipeline]
# Generation 3 - Current Pareto front scores:
#           on Progress:  65%|██████▌   | 78/120 [8:14:08<4:56:19, 423.31s/pipeline]
# 1	0.962933304617718	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=1.0, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=14, ExtraTreesClassifier__n_estimators=DEFAULT)
#           on Progress:  65%|██████▌   | 78/120 [8:14:08<4:56:19, 423.31s/pipeline]
#           on Progress:  65%|██████▌   | 78/120 [8:14:11<3:27:45, 296.79s/pipeline]
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
#           on Progress:  65%|██████▌   | 78/120 [8:14:11<3:27:45, 296.79s/pipeline]
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
#           on Progress:  66%|██████▌   | 79/120 [8:14:11<3:22:48, 296.79s/pipeline]
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
#           on Progress:  67%|██████▋   | 80/120 [8:14:11<3:17:51, 296.79s/pipeline]
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
#           on Progress:  68%|██████▊   | 81/120 [8:14:11<3:12:54, 296.79s/pipeline]
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
#           on Progress:  73%|███████▎  | 88/120 [8:41:29<2:16:45, 256.43s/pipeline]
# Skipped pipeline #91 due to time out. Continuing to the next pipeline.
#           on Progress:  80%|████████  | 96/120 [8:51:54<1:04:53, 162.22s/pipeline]
# Generation 4 - Current Pareto front scores:
#           on Progress:  80%|████████  | 96/120 [8:51:54<1:04:53, 162.22s/pipeline]
# 1	0.962933304617718	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=1.0, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=14, ExtraTreesClassifier__n_estimators=DEFAULT)
#           on Progress:  80%|████████  | 96/120 [8:51:54<1:04:53, 162.22s/pipeline]
#           on Progress:  80%|████████  | 96/120 [8:51:54<1:04:53, 162.22s/pipeline]
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
#           on Progress:  81%|████████  | 97/120 [8:51:56<43:46, 114.19s/pipeline]
# Pipeline encountered that has previously been evaluated during the optimization process. Using the score from the previous evaluation.
#           on Progress:  82%|████████▎ | 99/120 [9:15:14<1:41:23, 289.67s/pipeline]
# Skipped pipeline #101 due to time out. Continuing to the next pipeline.
#           on Progress:  84%|████████▍ | 101/120 [9:15:14<1:31:43, 289.67s/pipeline]
# Skipped pipeline #102 due to time out. Continuing to the next pipeline.
#           on Progress:  96%|█████████▌| 115/120 [9:29:37<09:30, 114.19s/pipeline] ]
# Generation 5 - Current Pareto front scores:
#           on Progress:  96%|█████████▌| 115/120 [9:29:37<09:30, 114.19s/pipeline]
# 1	0.962933304617718	ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=1.0, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=14, ExtraTreesClassifier__n_estimators=DEFAULT)
#           on Progress:  96%|█████████▌| 115/120 [9:29:37<09:30, 114.19s/pipeline]
# 0.96752

# %%
k_df_split = utility_functions.build_cross_validation_sets(data, 5)

# %%
X_test = k_df_split[0][0]
y_test = k_df_split[0][1]
X_train, y_train = shuffle(pd.concat([data[0] for data in k_df_split[1:]]), pd.concat([data[1] for data in k_df_split[1:]]))
# Out:
#   File "<ipython-input-10-b475ff9d6c95>", line 3
#     X_train, y_train = shuffle(pd.concat([data[0] for data in k_df_split[1:]]), pd.concat([data[1] for data in k_df_split[1:]])
#                                                                                                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
# Out:
#            4         5         6         7         8         9         10   \
# 0     0.203000  0.214500  0.171340  0.184390  0.168370  0.127920  0.155960
# 1     0.016152  0.013826  0.023646  0.019253  0.017961  0.017315  0.024034
# 2     0.023905  0.027006  0.018736  0.014472  0.021321  0.026102  0.010208
# 3     0.089030  0.078175  0.072361  0.085153  0.083990  0.095103  0.095232
# 4     0.035276  0.041995  0.033079  0.025714  0.023905  0.022871  0.021191
# 5     0.139940  0.121200  0.139680  0.141490  0.130120  0.159190  0.138910
# 6     0.018607  0.037731  0.059568  0.015377  0.036310  0.071844  0.039928
# 7     0.215790  0.221480  0.243960  0.235950  0.232460  0.252880  0.261790
# 8     0.036826  0.054271  0.067451  0.025843  0.030753  0.046388  0.025972
# 9     0.212170  0.217210  0.206750  0.196280  0.195240  0.199770  0.177280
# 10    0.173280  0.198730  0.229620  0.220180  0.249260  0.287120  0.266700
# 11    0.017056  0.016798  0.013955  0.017056  0.014860  0.009562  0.014472
# 12    0.017703  0.016023  0.014989  0.009691  0.005815  0.015506  0.016798
# 13    0.168110  0.162680  0.163330  0.171730  0.174180  0.186200  0.173800
# 14    0.014989  0.007882  0.009045  0.016410  0.018736  0.017703  0.010725
# 15    0.037085  0.034242  0.020416  0.029720  0.024293  0.015764  0.027523
# 16    0.338420  0.327170  0.329110  0.363100  0.353400  0.354310  0.410650
# 17    0.051428  0.032433  0.018995  0.024939  0.009820  0.005039  0.020933
# 18    0.110480  0.108670  0.093552  0.017056  0.024293  0.020158  0.016152
# 19    0.272390  0.284270  0.286730  0.266570  0.271870  0.276000  0.251450
# 20    0.325620  0.309600  0.294870  0.323940  0.314770  0.309730  0.313860
# 21    0.433780  0.437780  0.412070  0.176510  0.171340  0.146270  0.026618
# 22    0.047293  0.039928  0.040961  0.024163  0.022354  0.035276  0.034630
# 23    0.218890  0.240340  0.227290  0.207780  0.221990  0.215660  0.198600
# 24    0.056855  0.068097  0.068743  0.043416  0.041220  0.025972  0.035793
# 25    0.010596  0.019253  0.016410  0.016798  0.013051  0.016410  0.020545
# 26    0.246290  0.245120  0.248090  0.240080  0.231940  0.232980  0.230260
# 27    0.162040  0.189040  0.207000  0.183620  0.206100  0.204030  0.199640
# 28    0.211400  0.236340  0.269410  0.173800  0.205190  0.237240  0.142010
# 29    0.171210  0.169400  0.181940  0.180900  0.177030  0.181030  0.178580
# ...        ...       ...       ...       ...       ...       ...       ...
# 8720  0.296960  0.277090  0.253910  0.311320  0.287210  0.264770  0.330080
# 8721  0.276170  0.307640  0.334500  0.286110  0.312970  0.334130  0.286480
# 8722  0.540750  0.525670  0.523460  0.516470  0.511130  0.519600  0.540390
# 8723  0.188780  0.134680  0.084085  0.216740  0.172950  0.144800  0.210300
# 8724  0.248390  0.284270  0.314080  0.244890  0.276170  0.318860  0.225940
# 8725  0.591540  0.587490  0.587670  0.592640  0.570750  0.561360  0.602390
# 8726  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8727  0.547380  0.541490  0.525670  0.505980  0.482980  0.463290  0.470650
# 8728  0.318490  0.324010  0.304880  0.341120  0.320880  0.263660  0.343700
# 8729  0.006808  0.010672  0.006072  0.009200  0.014351  0.011960  0.013615
# 8730  0.052070  0.043054  0.037902  0.042502  0.038638  0.027967  0.052254
# 8731  0.592640  0.634040  0.666050  0.621900  0.657770  0.667160  0.626860
# 8732  0.595030  0.577920  0.549950  0.567070  0.529530  0.515730  0.576820
# 8733  0.012328  0.015639  0.012328  0.013799  0.014719  0.012695  0.017479
# 8734  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8735  0.567990  0.586570  0.566510  0.521620  0.561360  0.586750  0.507450
# 8736  0.607180  0.580310  0.516470  0.596320  0.584910  0.563750  0.551980
# 8737  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8738  0.211410  0.264030  0.301560  0.234960  0.266790  0.293100  0.260170
# 8739  0.262370  0.272310  0.280400  0.282980  0.282240  0.270650  0.274890
# 8740  0.522360  0.498620  0.480960  0.446920  0.429440  0.434590  0.407360
# 8741  0.531370  0.548850  0.564670  0.547560  0.553450  0.557500  0.525300
# 8742  0.681880  0.611780  0.531190  0.647650  0.549220  0.471940  0.638090
# 8743  0.556950  0.579760  0.595400  0.538910  0.568720  0.577920  0.511320
# 8744  0.675990  0.660350  0.648570  0.637170  0.618030  0.599450  0.587490
# 8745  0.224470  0.192270  0.161910  0.165040  0.116840  0.073597  0.080589
# 8746  0.484080  0.481510  0.503770  0.476910  0.476720  0.485920  0.479670
# 8747  0.303040  0.304690  0.317570  0.297700  0.312600  0.327140  0.292360
# 8748  0.424290  0.428520  0.428150  0.410300  0.409750  0.400920  0.391170
# 8749  0.059614  0.077645  0.073413  0.069181  0.085005  0.079301  0.072493
#
#            11        12        13     ...          612       613       614  \
# 0     0.129340  0.096136  0.097075    ...     0.033718  0.030932  0.039024
# 1     0.028298  0.018736  0.007054    ...     0.033718  0.030932  0.039024
# 2     0.023130  0.026102  0.001496    ...     0.033718  0.030932  0.039024
# 3     0.105700  0.125340  0.406130    ...     0.033718  0.030932  0.039024
# 4     0.014472  0.024293  0.024734    ...     0.033718  0.030932  0.039024
# 5     0.138390  0.170820  0.424910    ...     0.033718  0.030932  0.039024
# 6     0.055821  0.071844  0.019849    ...     0.033718  0.030932  0.039024
# 7     0.259210  0.264250  0.126180    ...     0.033718  0.030932  0.039024
# 8     0.043287  0.057889  0.026872    ...     0.033718  0.030932  0.039024
# 9     0.190460  0.214370  0.078478    ...     0.033718  0.030932  0.039024
# 10    0.279880  0.295260  0.117320    ...     0.033718  0.030932  0.039024
# 11    0.011629  0.006848  0.024001    ...     0.033718  0.030932  0.039024
# 12    0.021321  0.027006  0.005222    ...     0.033718  0.030932  0.039024
# 13    0.171210  0.185550  0.171550    ...     0.033718  0.030932  0.039024
# 14    0.022096  0.023646  0.004092    ...     0.033718  0.030932  0.039024
# 15    0.016798  0.020158  0.020001    ...     0.033718  0.030932  0.039024
# 16    0.410390  0.417110  0.116560    ...     0.033718  0.030932  0.039024
# 17    0.023646  0.028427  0.042751    ...     0.033718  0.030932  0.039024
# 18    0.028169  0.027652  0.075058    ...     0.033718  0.030932  0.039024
# 19    0.255330  0.270580  0.163800    ...     0.033718  0.030932  0.039024
# 20    0.307150  0.308570  0.139670    ...     0.033718  0.030932  0.039024
# 21    0.022613  0.018736  0.277820    ...     0.033718  0.030932  0.039024
# 22    0.031658  0.027265  0.029284    ...     0.033718  0.030932  0.039024
# 23    0.204160  0.206100  0.095212    ...     0.033718  0.030932  0.039024
# 24    0.035017  0.021708  0.052278    ...     0.033718  0.030932  0.039024
# 25    0.006978  0.009045  0.003603    ...     0.033718  0.030932  0.039024
# 26    0.223280  0.231040  0.125170    ...     0.033718  0.030932  0.039024
# 27    0.206360  0.195890  0.162880    ...     0.033718  0.030932  0.039024
# 28    0.171600  0.187880  0.239920    ...     0.033718  0.030932  0.039024
# 29    0.175470  0.175730  0.081990    ...     0.033718  0.030932  0.039024
# ...        ...       ...       ...    ...          ...       ...       ...
# 8720  0.306720  0.284080  0.122470    ...     0.096969  0.095748  0.094527
# 8721  0.314630  0.333760  0.133210    ...     0.096969  0.095748  0.094527
# 8722  0.528610  0.527140  0.166140    ...     0.096969  0.095748  0.094527
# 8723  0.195580  0.206070  0.119390    ...     0.096969  0.095748  0.094527
# 8724  0.262370  0.305610  0.191470    ...     0.096969  0.095748  0.094527
# 8725  0.573510  0.555290  0.161660    ...     0.096969  0.095748  0.094527
# 8726  0.000000  0.000000  0.000000    ...     0.096969  0.095748  0.094527
# 8727  0.441400  0.421900  0.151010    ...     0.096969  0.095748  0.094527
# 8728  0.295120  0.207360  0.127110    ...     0.096969  0.095748  0.094527
# 8729  0.011040  0.007544  0.001312    ...     0.096969  0.095748  0.094527
# 8730  0.045630  0.035143  0.309880    ...     0.096969  0.095748  0.094527
# 8731  0.658140  0.652620  0.156870    ...     0.096969  0.095748  0.094527
# 8732  0.524200  0.518860  0.227640    ...     0.096969  0.095748  0.094527
# 8733  0.017479  0.014351  0.002411    ...     0.096969  0.095748  0.094527
# 8734  0.000000  0.000000  0.000000    ...     0.096969  0.095748  0.094527
# 8735  0.535600  0.571300  0.122320    ...     0.096969  0.095748  0.094527
# 8736  0.567430  0.594480  0.219890    ...     0.096969  0.095748  0.094527
# 8737  0.000000  0.000000  0.000000    ...     0.096969  0.095748  0.094527
# 8738  0.278750  0.309110  0.183750    ...     0.096969  0.095748  0.094527
# 8739  0.263480  0.243790  0.088015    ...     0.096969  0.095748  0.094527
# 8740  0.406260  0.419140  0.126320    ...     0.096969  0.095748  0.094527
# 8741  0.537990  0.537440  0.160130    ...     0.096969  0.095748  0.094527
# 8742  0.593190  0.571110  0.212650    ...     0.096969  0.095748  0.094527
# 8743  0.528430  0.540200  0.150490    ...     0.096969  0.095748  0.094527
# 8744  0.556390  0.518120  0.181860    ...     0.096969  0.095748  0.094527
# 8745  0.050598  0.019135  0.117010    ...     0.096969  0.095748  0.094527
# 8746  0.485920  0.494200  0.116580    ...     0.096969  0.095748  0.094527
# 8747  0.322910  0.348300  0.101320    ...     0.096969  0.095748  0.094527
# 8748  0.389510  0.371110  0.117160    ...     0.096969  0.095748  0.094527
# 8749  0.088500  0.091812  0.068911    ...     0.096969  0.095748  0.094527
#
#            615       616       617       618       619       620       621
# 0     0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 1     0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 2     0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 3     0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 4     0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 5     0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 6     0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 7     0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 8     0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 9     0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 10    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 11    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 12    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 13    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 14    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 15    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 16    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 17    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 18    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 19    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 20    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 21    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 22    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 23    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 24    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 25    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 26    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 27    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 28    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# 29    0.052403  0.062265  0.041420  0.030554  0.030853  0.034379  0.033803
# ...        ...       ...       ...       ...       ...       ...       ...
# 8720  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8721  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8722  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8723  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8724  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8725  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8726  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8727  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8728  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8729  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8730  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8731  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8732  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8733  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8734  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8735  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8736  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8737  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8738  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8739  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8740  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8741  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8742  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8743  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8744  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8745  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8746  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8747  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8748  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
# 8749  0.093306  0.092084  0.090863  0.089642  0.088421  0.087199  0.085978
#
# [8750 rows x 618 columns]
